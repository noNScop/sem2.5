# %% [markdown]
# # 1) Create a notebook like this one, but for NLP, and use it to find which words in a movie review are most significant in assessing the sentiment of a particular movie review.

# %%
from fastai.text.all import *
import pandas as pd

# %%
dls = TextDataLoaders.from_folder(untar_data(URLs.IMDB), valid='test')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='144441344' class='' max='144440600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [144441344/144440600 00:03&lt;00:00]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn = text_classifier_learner(dls, AWD_LSTM, drop_mult=0.5, metrics=accuracy)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='105070592' class='' max='105067061' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [105070592/105067061 00:02&lt;00:00]
#     </div>

# %%
learn.fine_tune(4, 1e-2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.458757</td>
#       <td>0.397854</td>
#       <td>0.822600</td>
#       <td>03:29</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.302143</td>
#       <td>0.248140</td>
#       <td>0.903680</td>
#       <td>07:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.232062</td>
#       <td>0.207345</td>
#       <td>0.916880</td>
#       <td>07:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.180036</td>
#       <td>0.186839</td>
#       <td>0.928520</td>
#       <td>07:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.144407</td>
#       <td>0.192711</td>
#       <td>0.930040</td>
#       <td>07:08</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Read text files, we need 2, for this LSTM works only with batch_size = 2

# %%
file1 = '/root/.fastai/data/imdb/test/pos/0_10.txt'
file2 = '/root/.fastai/data/imdb/test/neg/9998_1.txt'

with open(file1, 'r') as file:
    text1 = file.read()

with open(file2, 'r') as file:
    text2 = file.read()

print(text1)
print(text2)
# Out:
# I went and saw this movie last night after being coaxed to by a few friends of mine. I'll admit that I was reluctant to see it because from what I knew of Ashton Kutcher he was only able to do comedy. I was wrong. Kutcher played the character of Jake Fischer very well, and Kevin Costner played Ben Randall with such professionalism. The sign of a good movie is that it can toy with our emotions. This one did exactly that. The entire theater (which was sold out) was overcome by laughter during the first half of the movie, and were moved to tears during the second half. While exiting the theater I not only saw many women in tears, but many full grown men as well, trying desperately not to let anyone see them crying. This movie was great, and I suggest that you go see it before you judge.
# I occasionally let my kids watch this garbage so they will understand just how pathetic the show's "contestants" are. They are pathetic not because they are fat, but because they whore their dignity for a few minutes of fame and fortune.<br /><br />For anyone to appear on National TV and blubber, sniffle, and whine about being fat (entirely their own fault) is nauseating. What does this say about us as a nation? Does it suggest that your lifestyle choices, and the consequences of them, aren't our responsibility? <br /><br />"The Biggest Loser" is an appropriate title, but it has nothing to do with one's weight.<br /><br />Absolute trash.

# %% [markdown]
# Tokenize, numericalize, pad and transform texts into tensors

# %%
tokens1 = dls.tokenizer(text1)
tokens2 = dls.tokenizer(text2)

indices1 = list(dls.numericalize(tokens1))
indices2 = list(dls.numericalize(tokens2))

if len(indices1) > len(indices2):
    diff = len(indices1) - len(indices2)
    indices2 += [1] * diff
else:
    diff = len(indices2) - len(indices1)
    indices1 += [1] * diff

x1 = torch.tensor(indices1).unsqueeze(0)
x2 = torch.tensor(indices2).unsqueeze(0)

x = torch.cat((x1, x2))

# %%
x.shape
# Out:
# torch.Size([2, 185])

# %% [markdown]
# Our model is very confident that the first review is positive, and the second is negative

# %%
F.softmax(learn.model.eval()(x.cuda())[0], dim=1)
# Out:
# tensor([[0.0023, 0.9977],
#         [0.9916, 0.0084]], device='cuda:0', grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# Collect information about activations and gradients with hooks

# %%
# I am using fastai hook as pytorch is not cooperating with fastai custom sentence encoder
ghook = Hook(learn.model[0], lambda m, gi, go: go[0].detach().clone())
hook = Hook(learn.model[0], lambda m, i, o: o[0].detach().clone())

output = learn.model.eval()(x.cuda())
act1 = hook.stored[0]
act2 = hook.stored[1]
output[0][0,1].backward(retain_graph=True)

learn.model.zero_grad()

output[0][1,0].backward()
grad1 = ghook.stored[0]
grad2 = ghook.stored[1]

# %%
w1 = grad1.mean(dim=0, keepdim=True)
relevance1 = (w1 * act1).sum(1)

w2 = grad2.mean(dim=0, keepdim=True)
relevance2 = (w2 * act2).sum(1)

# %%
first = relevance1.cpu().numpy()
decoded_1 = [dls.vocab[0][idx] for idx in indices1]
second = relevance2.cpu().numpy()
decoded_2 = [dls.vocab[0][idx] for idx in indices2]

# %%
data = {
    'Token relevance in seq 1': first,
    'First review': decoded_1,
    'Token relevance in seq 2': second,
    'Second review': decoded_2
}

df = pd.DataFrame(data)
pd.set_option('display.max_rows', None)

top10 = df.nlargest(10, 'Token relevance in seq 1')[['Token relevance in seq 1', 'First review']]

top10
# Out:
#      Token relevance in seq 1 First review
# 173                  6.306051          and
# 67                   6.231395        xxmaj
# 174                  6.226990            i
# 80                   5.799209        xxmaj
# 175                  5.482003      suggest
# 81                   5.415201          the
# 85                   5.193146         good
# 172                  5.173337            ,
# 182                  5.151177          you
# 183                  5.041526        judge

# %%
top10 = df.nlargest(10, 'Token relevance in seq 2')[['Token relevance in seq 2', 'Second review']]

top10
# Out:
#      Token relevance in seq 2 Second review
# 28                   4.616793           not
# 8                    4.136954       garbage
# 46                   4.004530           and
# 64                   3.690307             ,
# 9                    3.657064            so
# 65                   3.650867           and
# 72                   3.641071         their
# 44                   3.614698            of
# 131                  3.581680            's
# 132                  3.558535        weight

# %% [markdown]
# Most of the words with the biggest influence seem irrelevant. That is because LSTM carries a hidden state, so an influence of a single token is carried over to the next tokens. That makes finding significant tokens quite challenging. I think that it makes more sense to read through the entire sequence and see how the relevance of tokens fluctuates.

# %%
df
# Out:
#      Token relevance in seq 1     First review  Token relevance in seq 2  \
# 0                    0.015148            xxbos                  0.261646
# 1                    0.594359                i                  0.608518
# 2                    1.306140             went                  1.229835
# 3                    2.802287              and                  2.058353
# 4                    2.462230              saw                  2.636405
# 5                    2.589355             this                  2.534678
# 6                    2.188641            movie                  2.164536
# 7                    2.952161             last                  2.215730
# 8                    3.125645            night                  4.136954
# 9                    3.340211            after                  3.657064
# 10                   4.558835            being                  3.384406
# 11                   3.255110           coaxed                  2.799522
# 12                   2.961213               to                  2.102542
# 13                   2.773313               by                  2.332243
# 14                   2.475733                a                  2.116767
# 15                   2.710660              few                  2.793557
# 16                   2.446015          friends                  3.393943
# 17                   2.885311               of                  3.027012
# 18                   3.292213             mine                  3.555121
# 19                   2.275288                .                  3.110165
# 20                   3.099249            xxmaj                  2.699082
# 21                   3.558619                i                  2.775829
# 22                   2.850893              'll                  2.627354
# 23                   2.500840            admit                  1.733032
# 24                   2.071738             that                  2.593643
# 25                   3.069249                i                  2.693981
# 26                   3.559493              was                  2.750489
# 27                   2.709439        reluctant                  3.471096
# 28                   3.047659               to                  4.616793
# 29                   3.591479              see                  3.499702
# 30                   3.453217               it                  3.371360
# 31                   2.795825          because                  3.539214
# 32                   2.883697             from                  2.951904
# 33                   3.197213             what                  3.189283
# 34                   3.715876                i                  3.193330
# 35                   3.420390             knew                  2.524868
# 36                   3.425841               of                  2.625549
# 37                   3.436034            xxmaj                  3.165012
# 38                   2.949549           ashton                  3.191822
# 39                   3.740057            xxmaj                  3.350245
# 40                   2.752069          kutcher                  2.851758
# 41                   3.640597               he                  2.490147
# 42                   4.043926              was                  2.316886
# 43                   3.898013             only                  2.089980
# 44                   2.204573             able                  3.614698
# 45                   2.967098               to                  2.807200
# 46                   3.272933               do                  4.004530
# 47                   2.866981           comedy                  3.014022
# 48                   2.256193                .                  2.135972
# 49                   3.201402                i                  2.477131
# 50                   3.738418              was                  3.004569
# 51                   2.236825            wrong                  2.141001
# 52                   1.705290                .                  2.352974
# 53                   2.349128            xxmaj                  2.620378
# 54                   1.790758          kutcher                  2.620337
# 55                   1.711600           played                  2.274232
# 56                   1.748479              the                  2.584710
# 57                   1.957927        character                  2.198799
# 58                   1.829645               of                  2.034923
# 59                   1.480556            xxmaj                  1.908563
# 60                   1.362661             jake                  2.409743
# 61                   0.974955            xxmaj                  3.017249
# 62                   1.312943          fischer                  2.533405
# 63                   1.942091             very                  3.555864
# 64                   2.866210             well                  3.690307
# 65                   3.926474                ,                  3.650867
# 66                   4.491345              and                  3.161957
# 67                   6.231395            xxmaj                  2.747515
# 68                   4.226161            kevin                  3.399978
# 69                   4.782516            xxmaj                  2.971258
# 70                   3.473643          costner                  2.535911
# 71                   3.435763           played                  3.478375
# 72                   4.566195            xxmaj                  3.641071
# 73                   2.889961              ben                  3.470514
# 74                   3.185512            xxmaj                  2.171390
# 75                   2.489907          randall                  2.065850
# 76                   3.229158             with                  2.414938
# 77                   3.566028             such                  2.181431
# 78                   3.269874  professionalism                  1.887716
# 79                   2.796853                .                  2.875859
# 80                   5.799209            xxmaj                  2.577448
# 81                   5.415201              the                  2.260267
# 82                   4.536170             sign                  3.397777
# 83                   4.329601               of                  3.529640
# 84                   3.958031                a                  3.353602
# 85                   5.193146             good                  3.170998
# 86                   4.740786            movie                  3.177527
# 87                   4.555500               is                  3.428341
# 88                   4.025773             that                  3.096254
# 89                   3.750609               it                  2.662387
# 90                   3.604868              can                  3.094911
# 91                   3.282071              toy                  2.574387
# 92                   3.368003             with                  3.091341
# 93                   3.996795              our                  2.967245
# 94                   3.281830         emotions                  2.564606
# 95                   2.590333                .                  2.671242
# 96                   4.407678            xxmaj                  3.549711
# 97                   3.800911             this                  3.516928
# 98                   3.018921              one                  3.185954
# 99                   2.608914              did                  2.833038
# 100                  2.585240          exactly                  1.875887
# 101                  3.098233             that                  2.500864
# 102                  2.589174                .                  2.900659
# 103                  4.402549            xxmaj                  2.881220
# 104                  4.692971              the                  2.795766
# 105                  4.332276           entire                  2.959188
# 106                  3.659497          theater                  2.695505
# 107                  2.816363                (                  3.138152
# 108                  3.206550            which                  2.373281
# 109                  3.143804              was                  1.746078
# 110                  2.111643             sold                  2.186260
# 111                  1.761364              out                  1.593133
# 112                  2.225087                )                  2.313799
# 113                  2.625386              was                  2.659499
# 114                  2.526221         overcome                  1.698848
# 115                  2.884722               by                  2.191502
# 116                  3.681850         laughter                  2.067979
# 117                  3.347366           during                  2.283415
# 118                  3.243344              the                  2.237350
# 119                  2.348181            first                  1.869583
# 120                  1.890386             half                  2.127483
# 121                  2.083203               of                  2.077165
# 122                  1.996636              the                  1.946148
# 123                  1.599526            movie                  2.108431
# 124                  2.101068                ,                  1.585844
# 125                  3.183126              and                  1.468751
# 126                  3.727195             were                  1.984909
# 127                  2.586073            moved                  3.055627
# 128                  3.002328               to                  2.823864
# 129                  2.515312            tears                  2.641273
# 130                  2.968330           during                  3.168029
# 131                  2.984193              the                  3.581680
# 132                  2.537098           second                  3.558535
# 133                  2.172767             half                  2.389094
# 134                  2.125004                .                  2.567457
# 135                  4.037161            xxmaj                  3.029473
# 136                  3.880563            while                  2.654757
# 137                  3.495403          exiting                  3.160445
# 138                  3.729822              the                  2.794364
# 139                  4.042881          theater                  2.838206
# 140                  4.045907                i                  2.744362
# 141                  4.670926              not                  2.498776
# 142                  4.612153             only                  2.320095
# 143                  4.162243              saw                  2.144760
# 144                  4.134230             many                  0.000000
# 145                  4.344054            women                  0.000000
# 146                  4.149317               in                  0.000000
# 147                  3.240889            tears                  0.000000
# 148                  3.960099                ,                  0.000000
# 149                  4.299494              but                  0.000000
# 150                  4.643241             many                  0.000000
# 151                  4.577538             full                  0.000000
# 152                  4.933151            grown                  0.000000
# 153                  4.435530              men                  0.000000
# 154                  4.863610               as                  0.000000
# 155                  4.099215             well                  0.000000
# 156                  4.442804                ,                  0.000000
# 157                  2.755902           trying                  0.000000
# 158                  2.237739      desperately                  0.000000
# 159                  3.126080              not                  0.000000
# 160                  2.626169               to                  0.000000
# 161                  2.735926              let                  0.000000
# 162                  3.021138           anyone                  0.000000
# 163                  3.210834              see                  0.000000
# 164                  3.167364             them                  0.000000
# 165                  2.982985           crying                  0.000000
# 166                  2.502201                .                  0.000000
# 167                  3.790436            xxmaj                  0.000000
# 168                  3.401714             this                  0.000000
# 169                  2.386124            movie                  0.000000
# 170                  2.791994              was                  0.000000
# 171                  3.853068            great                  0.000000
# 172                  5.173337                ,                  0.000000
# 173                  6.306051              and                  0.000000
# 174                  6.226990                i                  0.000000
# 175                  5.482003          suggest                  0.000000
# 176                  4.882579             that                  0.000000
# 177                  5.015285              you                  0.000000
# 178                  3.796432               go                  0.000000
# 179                  4.505948              see                  0.000000
# 180                  4.202174               it                  0.000000
# 181                  4.721441           before                  0.000000
# 182                  5.151177              you                  0.000000
# 183                  5.041526            judge                  0.000000
# 184                  3.971859                .                  0.000000
#
#       Second review
# 0             xxbos
# 1                 i
# 2      occasionally
# 3               let
# 4                my
# 5              kids
# 6             watch
# 7              this
# 8           garbage
# 9                so
# 10             they
# 11             will
# 12       understand
# 13             just
# 14              how
# 15         pathetic
# 16              the
# 17             show
# 18               's
# 19                "
# 20      contestants
# 21                "
# 22              are
# 23                .
# 24            xxmaj
# 25             they
# 26              are
# 27         pathetic
# 28              not
# 29          because
# 30             they
# 31              are
# 32              fat
# 33                ,
# 34              but
# 35          because
# 36             they
# 37            whore
# 38            their
# 39          dignity
# 40              for
# 41                a
# 42              few
# 43          minutes
# 44               of
# 45             fame
# 46              and
# 47          fortune
# 48                .
# 49             \n\n
# 50            xxmaj
# 51              for
# 52           anyone
# 53               to
# 54           appear
# 55               on
# 56            xxmaj
# 57         national
# 58             xxup
# 59               tv
# 60              and
# 61          blubber
# 62                ,
# 63          sniffle
# 64                ,
# 65              and
# 66            whine
# 67            about
# 68            being
# 69              fat
# 70                (
# 71         entirely
# 72            their
# 73              own
# 74            fault
# 75                )
# 76               is
# 77       nauseating
# 78                .
# 79            xxmaj
# 80             what
# 81             does
# 82             this
# 83              say
# 84            about
# 85               us
# 86               as
# 87                a
# 88           nation
# 89                ?
# 90            xxmaj
# 91             does
# 92               it
# 93          suggest
# 94             that
# 95             your
# 96        lifestyle
# 97          choices
# 98                ,
# 99              and
# 100             the
# 101    consequences
# 102              of
# 103            them
# 104               ,
# 105             are
# 106             n't
# 107             our
# 108  responsibility
# 109               ?
# 110            \n\n
# 111               "
# 112             the
# 113           xxmaj
# 114         biggest
# 115           xxmaj
# 116           loser
# 117               "
# 118              is
# 119              an
# 120     appropriate
# 121           title
# 122               ,
# 123             but
# 124              it
# 125             has
# 126         nothing
# 127              to
# 128              do
# 129            with
# 130             one
# 131              's
# 132          weight
# 133               .
# 134            \n\n
# 135           xxmaj
# 136        absolute
# 137           trash
# 138               .
# 139           xxpad
# 140           xxpad
# 141           xxpad
# 142           xxpad
# 143           xxpad
# 144           xxpad
# 145           xxpad
# 146           xxpad
# 147           xxpad
# 148           xxpad
# 149           xxpad
# 150           xxpad
# 151           xxpad
# 152           xxpad
# 153           xxpad
# 154           xxpad
# 155           xxpad
# 156           xxpad
# 157           xxpad
# 158           xxpad
# 159           xxpad
# 160           xxpad
# 161           xxpad
# 162           xxpad
# 163           xxpad
# 164           xxpad
# 165           xxpad
# 166           xxpad
# 167           xxpad
# 168           xxpad
# 169           xxpad
# 170           xxpad
# 171           xxpad
# 172           xxpad
# 173           xxpad
# 174           xxpad
# 175           xxpad
# 176           xxpad
# 177           xxpad
# 178           xxpad
# 179           xxpad
# 180           xxpad
# 181           xxpad
# 182           xxpad
# 183           xxpad
# 184           xxpad
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Token relevance in seq 1'].plot(kind='hist', bins=20, title='Token relevance in seq 1')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Token relevance in seq 2'].plot(kind='hist', bins=20, title='Token relevance in seq 2')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='Token relevance in seq 1', y='Token relevance in seq 2', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Token relevance in seq 1'].plot(kind='line', figsize=(8, 4), title='Token relevance in seq 1')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['Token relevance in seq 2'].plot(kind='line', figsize=(8, 4), title='Token relevance in seq 2')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# For the first review we can see how the growth in sentiment is reflected on the graph with clear up trend which is quite fascinating. While the second review is remaining equally negative from the beginning to the end, and so the graph is oscilating on a constant interval. Another thing that's worth pointing out is that it took 6 padding tokens to make LSTM realise that the sequence is finished which again, proves the influence of hidden state I mentioned before.
